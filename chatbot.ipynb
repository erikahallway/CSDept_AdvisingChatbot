# %% [markdown]
# # Create a Question Answering Chatbot for the Graduate Advising system

# %% [markdown]
# ### Install needed libraries

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\erika\anaconda3\lib\site-packages (0.27.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: aiohttp in c:\users\erika\anaconda3\lib\site-packages (from openai) (3.6.3)
# Requirement already satisfied: requests>=2.20 in c:\users\erika\anaconda3\lib\site-packages (from openai) (2.24.0)
# Requirement already satisfied: tqdm in c:\users\erika\anaconda3\lib\site-packages (from openai) (4.62.3)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\erika\anaconda3\lib\site-packages (from aiohttp->openai) (3.0.4)
# Requirement already satisfied: multidict<5.0,>=4.5 in c:\users\erika\anaconda3\lib\site-packages (from aiohttp->openai) (4.7.6)
# Requirement already satisfied: yarl<1.6.0,>=1.0 in c:\users\erika\anaconda3\lib\site-packages (from aiohttp->openai) (1.5.1)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\erika\anaconda3\lib\site-packages (from aiohttp->openai) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\erika\anaconda3\lib\site-packages (from aiohttp->openai) (19.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\erika\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erika\anaconda3\lib\site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\erika\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\erika\appdata\roaming\python\python38\site-packages (from tqdm->openai) (0.4.4)

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\erika\anaconda3\lib\site-packages (4.27.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (2020.6.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (1.18.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\erika\anaconda3\lib\site-packages (from transformers) (20.4)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: filelock in c:\users\erika\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in c:\users\erika\anaconda3\lib\site-packages (from transformers) (2.24.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\erika\appdata\roaming\python\python38\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\erika\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\erika\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: six in c:\users\erika\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\erika\anaconda3\lib\site-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erika\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\erika\anaconda3\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\erika\anaconda3\lib\site-packages (from requests->transformers) (2.10)

# %%
# %pip install pysimplegui
# Out:
# Collecting pysimplegui
#   Downloading PySimpleGUI-4.60.4-py3-none-any.whl (509 kB)
# Installing collected packages: pysimplegui
# Successfully installed pysimplegui-4.60.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Set up the model

# %%
# import needed libraries
import openai
import pandas as pd
import numpy as np
import pickle
import re
from transformers import GPT2TokenizerFast
from typing import Dict, List, Tuple
import PySimpleGUI as sg

# %%
openai.api_key = "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" #secret keys here: https://platform.openai.com/account/api-keys
COMPLETIONS_MODEL = "text-davinci-003"

# %%
#set the model for the task of document and query vector embedding
MODEL_NAME = "curie"

DOC_EMBEDDINGS_MODEL = f"text-search-{MODEL_NAME}-doc-001"
QUERY_EMBEDDINGS_MODEL = f"text-search-{MODEL_NAME}-query-001"

# %%
#add relevant context from the doc sections to a prompt by prepending them to the supplied query
MAX_SECTION_LEN = 500
SEPARATOR = "\n* "

tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")
separator_len = len(tokenizer.tokenize(SEPARATOR))

f"Context separator contains {separator_len} tokens"
# Out:
# 'Context separator contains 3 tokens'

# %%
#use the completions API - this allows us to provide an answer instead of just ingesting the question 
COMPLETIONS_API_PARAMS = {
    # We use temperature of 0.0 because it gives the most predictable, factual answer.
    "temperature": 0.0,
    "max_tokens": 300,
    "model": COMPLETIONS_MODEL,
}

# %% [markdown]
# ### Write helper functions

# %%
#create functions to get the embedding, get the document and query embedding, and computer the embedding
def get_embedding(text: str, model: str) -> List[float]:
    print("inside get_embedding")
    result = openai.Embedding.create(
      model=model,
      input=text)
    return result["data"][0]["embedding"]

def get_doc_embedding(text: str) -> List[float]:
    print("inside get_doc_embedding")
    return get_embedding(text, DOC_EMBEDDINGS_MODEL)

def get_query_embedding(text: str) -> List[float]:
    return get_embedding(text, QUERY_EMBEDDINGS_MODEL)

def compute_doc_embeddings(df: pd.DataFrame) -> Dict[Tuple[str, str], List[float]]:
    """
    Create an embedding for each row in the dataframe using the OpenAI Embeddings API.
    
    Return a dictionary that maps between each embedding vector and the index of the row that it corresponds to.
    """
    print("inside compute_doc_embedding")
    return {
        idx: get_doc_embedding(r.content.replace("\n", " ")) for idx, r in df.iterrows()
    }

# %%
#create function called load_embeddings that reads the document embeddings and their keys from csv 
def load_embeddings(fname: str) -> Dict[Tuple[str, str], List[float]]:
    """
    Read the document embeddings and their keys from a CSV.
    
    fname is the path to a CSV with exactly these named columns: 
        "title", "heading", "0", "1", ... up to the length of the embedding vectors.
    """
    
    df = pd.read_csv(fname, header=0)
    max_dim = max([int(c) for c in df.columns if c != "title" and c != "heading"])
    return {
           (r.title, r.heading): [r[str(i)] for i in range(max_dim + 1)] for _, r in df.iterrows()
    }

# %%
#calculate the similarity between vectors 
def vector_similarity(x: List[float], y: List[float]) -> float:
    """
    We could use cosine similarity or dot product to calculate the similarity between vectors.
    In practice, we have found it makes little difference. 
    """
    return np.dot(np.array(x), np.array(y))

# %%
#find the query embedding and compare it to the document embeddings to find the most relevant sections
def order_document_sections_by_query_similarity(query: str, contexts: Dict[Tuple[str, str], np.array]) -> List[Tuple[float, Tuple[str, str]]]:
    """
    Find the query embedding for the supplied query, and compare it against all of the pre-calculated document embeddings
    to find the most relevant sections. 
    
    Return the list of document sections, sorted by relevance in descending order.
    """
    query_embedding = get_query_embedding(query)
    
    document_similarities = sorted([
        (vector_similarity(query_embedding, doc_embedding), doc_index) for doc_index, doc_embedding in contexts.items()
    ], reverse=True)
    
    return document_similarities

# %%
#create function to construct the new prompt with the most relevant document sections
def construct_prompt(question: str, context_embeddings: dict, df: pd.DataFrame) -> str:
    """
    Fetch relevant 
    """
    most_relevant_document_sections = order_document_sections_by_query_similarity(question, context_embeddings)
    
    chosen_sections = []
    chosen_sections_len = 0
    chosen_sections_indexes = []
     
    for _, section_index in most_relevant_document_sections:
        # Add contexts until we run out of space.        
        document_section = df.loc[section_index]
        
        chosen_sections_len += document_section.tokens + separator_len
        if chosen_sections_len > MAX_SECTION_LEN:
            break
            
        chosen_sections.append(SEPARATOR + document_section.content.replace("\n", " "))
        chosen_sections_indexes.append(str(section_index))
            
    # Useful diagnostic information
    print(f"Selected {len(chosen_sections)} document sections:")
    print("\n".join(chosen_sections_indexes))
    
    header = """Answer the question as truthfully as possible using the provided context, and if the answer is not contained within the text below, say "I don't know."\n\nContext:\n"""
    
    return header + "".join(chosen_sections) + "\n\n Q: " + question + "\n A:"

# %%
#create function to answer query with the retrieved document text
def answer_query_with_context(
    query: str,
    df: pd.DataFrame,
    document_embeddings: Dict[Tuple[str, str], np.array],
    show_prompt: bool = False
) -> str:
    prompt = construct_prompt(
        query,
        document_embeddings,
        df
    )
    
    if show_prompt:
        print(prompt)

    response = openai.Completion.create(
                prompt=prompt,
                **COMPLETIONS_API_PARAMS
            )

    return response["choices"][0]["text"].strip(" \n")

# %% [markdown]
# ### Create dataset

# %% [markdown]
# Test other models (other than Davinci and Curie, as above)

# %% [raw]
# Steps:
#     1. Make a tiny little csv with our data
#     2. Test the code on that tiny little csv
#     3. Troubleshoot
#     4. Make bigger csv

# %%
df = pd.read_excel('grad_info.xlsx')

# %%
df.head()
# Out:
#                                                title  \
# 0             Graduate Program Overview Introduction
# 1         Graduate Program Overview Course Transfers
# 2           Graduate Program Overview Graduate Links
# 3  M.S. in Computer Science Overview Degree Plan ...
# 4  M.S. in Computer Science Overview Thesis, Proj...
#
#                                 heading  \
# 0                          Introduction
# 1                     Course Transfers
# 2                        Graduate Links
# 3  Degree Plan & Admission to Candidacy
# 4   Thesis, Project, or Report Advisory
#
#                                              content  tokens  Unnamed: 4  \
# 0  The Department of Computer Science at Texas Te...     NaN         NaN
# 1  A graduate course may be accepted for transfer...     NaN         NaN
# 2  Overview. Computer Science (Master of Science)...     NaN         NaN
# 3  The degree plan specifies information, such as...     NaN         NaN
# 4  Committee: All committee members must belong t...     NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
def count_tokens(text):
    return len(text.split())

# %%
# clean up the dataframe 
df = df.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'], axis=1)
df['tokens'] = df['content'].apply(count_tokens)

# %%
df
# Out:
#                                                 title  \
# 0              Graduate Program Overview Introduction
# 1          Graduate Program Overview Course Transfers
# 2            Graduate Program Overview Graduate Links
# 3   M.S. in Computer Science Overview Degree Plan ...
# 4   M.S. in Computer Science Overview Thesis, Proj...
# 5   M.S. in Computer Science Overview Course Trans...
# 6   M.S. in Compute Science Curriculum and Courses...
# 7   M.S. in Computer Science Curriculum and Course...
# 8   M.S. in Computer Science Curriculum and Course...
# 9   M.S. in Software and Security Engineering Intr...
# 10  M.S. in Software and Security Engineering Entr...
# 11  M.S. in Software and Security Engineering Degr...
# 12  M.S. in Software and Security Engineering Thes...
# 13  M.S. in Software and Security Engineering Cour...
# 14  M.S. in Software Engineering Curriculum & Cour...
# 15  M.S. in Software Engineering Curriculum & Cour...
# 16  M.S. in Software Engineering Curriculum and Co...
# 17  Doctor of Philosophy in Computer Science Overv...
# 18  Doctor of Philosophy in Computer Science Overv...
# 19  Doctor of Philosophy in Computer Science Disse...
# 20  Doctor of Philosophy in Computer Science Disse...
# 21  Doctor of Philosophy in Computer Science Quali...
# 22  Doctor of Philosophy in Computer Science Admis...
# 23  Doctor of Philosophy in Computer Science Final...
# 24  Doctor of Philosophy in Computer Science Resid...
# 25  Doctor of Philosophy in Computer Science Time ...
# 26  Doctor of Philosophy in Computer Science Cours...
# 27  Doctor of Philosophy in Computer Science Curri...
# 28  Doctor of Philosophy in Computer Science Curri...
# 29          Certificate Program Overview Introduction
# 30  Certificate Program Overview Certificate Degre...
# 31      Certificate Program Overview Course Transfers
# 32  Certificate Program Curriculum & Courses About...
# 33                  Financial Assistance Introduction
# 34       Financial Assistance Teaching Assistantships
# 35       Financial Assistance Research Assistantships
# 36      Financial Assistance Fellowships/Scholarships
# 37                       Graduate Admissions Overview
# 38             Graduate Admissions Requried Materials
# 39  Advising & Registration Core Course Rotation S...
# 40                        FAQ Graduate Admissions FAQ
#
#                                               heading  \
# 0                                        Introduction
# 1                                   Course Transfers
# 2                                      Graduate Links
# 3                Degree Plan & Admission to Candidacy
# 4                 Thesis, Project, or Report Advisory
# 5                                   Course Transfers
# 6                                          Curriculum
# 7      Example Plan of Full-Time Study (Thesis-Based)
# 8   Example Plan of Full-Time Study (Non-Thesis-Ba...
# 9                                        Introduction
# 10                              Entrance Requirements
# 11                                        Degree Plan
# 12               Thesis, Project, or Report Advisory
# 13                                  Course Transfers
# 14                            Curriculum (since 2013)
# 15                  Curriculum (prior to Summer 2013)
# 16                   Curriculum (prior to Fall 2011)
# 17                                       Introduction
# 18                                       Degree Plan
# 19                    Dissertation Advisory Committee
# 20                                      Dissertation
# 21                             Qualifying Examination
# 22                             Admission to Candidacy
# 23                                  Final Examination
# 24                                          Residency
# 25                                         Time Limit
# 26                                  Course Transfers
# 27                                Course Requirements
# 28                    Example Plan of Full-Time Study
# 29                                      Introduction
# 30                           Certificate Degree Plan
# 31                                  Course Transfers
# 32  About the Software Engineering Graduate Certif...
# 33                                       Introduction
# 34                            Teaching Assistantships
# 35                            Research Assistantships
# 36                           Fellowships/Scholarships
# 37                                           Overview
# 38                                 Required Materials
# 39                      Core Course Rotation Schedule
# 40                                                FAQ
#
#                                               content  tokens
# 0   The Department of Computer Science at Texas Te...     362
# 1   A graduate course may be accepted for transfer...     165
# 2   Overview. Computer Science (Master of Science)...      51
# 3   The degree plan specifies information, such as...     346
# 4   Committee: All committee members must belong t...     373
# 5   A graduate course may be accepted for transfer...     162
# 6   General Requirements: The Master of Science in...     362
# 7   Fall Semester: Graduate Core Course, Graduate ...      62
# 8   Fall Semester: Graduate Core Course, Graduate ...      76
# 9   Our Master of Science in Software and Security...     201
# 10  Applicants should have a Bachelor of Science i...      35
# 11  The degree plan for students pursuing a Master...     697
# 12  Committee: All committee members must belong t...     373
# 13  A graduate course may be accepted for transfer...     162
# 14  The Master of Science in Software Engineering ...     395
# 15  The Master of Science in Software Engineering ...     178
# 16  The Master of Science in Software Engineering ...     522
# 17  For the Ph.D. degree, students are required to...      63
# 18  The Ph.D. Degree Plan specifies information, s...     118
# 19  All committee members must belong to the gradu...      57
# 20  According to the Texas Tech Undergraduate & Gr...      79
# 21  The qualifying examination is given by the Dis...      74
# 22  After the Qualifying Examination is passed, th...      35
# 23  The Final Examination is a public oral examina...      57
# 24  Please read the Texas Tech Undergraduate & Gra...      43
# 25  All requirements must be completed within a pe...      22
# 26  A graduate course may be accepted for transfer...     215
# 27  12 hours of CS 8000 (Dissertation) are require...     173
# 28  Fall Semester − 6 course hours & CS 7000 with ...     121
# 29  The Department of Computer Science offers the ...      62
# 30  The Certificate Degree Plan specifies informat...      60
# 31  A graduate course may be accepted for transfer...     152
# 32  The Graduate Certificate in Software Engineeri...     176
# 33  The Department of Computer Science is committe...      35
# 34  All doctoral students are eligible to be award...     142
# 35  The number of research assistantships varies w...      65
# 36  The Graduate School offers several scholarship...      12
# 37  Admission to all graduate programs is granted ...     143
# 38  Each applicant must submit a formal applicatio...      93
# 39  Beginning with the fall 2013 semester, the sch...     157
# 40  My undergraduate major is not in computer scie...     495

# %% [markdown]
# ### Test on our data

# %%
#calcualte the embeddings from scratch
document_embeddings = compute_doc_embeddings(df)
# Out:
# inside compute_doc_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding
# inside get_doc_embedding
# inside get_embedding

# %%
#check out an example embedding 
example_entry = list(document_embeddings.items())[0]
print(f"{example_entry[0]} : {example_entry[1][:5]}... ({len(example_entry[1])} entries)")
# Out:
# 0 : [-0.02202020213007927, -0.0052879247814416885, -0.001247344072908163, 0.018745217472314835, -0.009870189242064953]... (4096 entries)

# %%
#find the most relevant sections related to a query
order_document_sections_by_query_similarity("What graduate degrees can I get?", document_embeddings)[:5]
# Out:
# inside get_embedding
# [(0.3625775753306756, 32),
#  (0.36205321429516313, 36),
#  (0.3533794092444966, 17),
#  (0.3517290422425496, 37),
#  (0.3482119440623258, 29)]

# %%
prompt = construct_prompt(
    "How many faculty members are in the department of computer science at Texas Tech?",
    document_embeddings,
    df
)

print("===\n", prompt)
# Out:
# inside get_embedding
# Selected 2 document sections:
# 0
# 19
# ===
#  Answer the question as truthfully as possible using the provided context, and if the answer is not contained within the text below, say "I don't know."
#
# Context:
#
# * The Department of Computer Science at Texas Tech University provides an excellent environment for furthering your studies. There are 18 faculty members, with research specialties across the entire spectrum of computer science. You can view the different research groups here (https://www.depts.ttu.edu/cs/research/index.php) or you can view our individual faculty member pages here (https://www.depts.ttu.edu/cs/faculty/). Our department offers five different graduate programs: Master of Science in Computer Science, Master of Science in Software and Security Engineering, Doctor of Philosophy in Computer Science, Graduate Certificate in Software Engineering, Graduate Certificate in Security. We also offer combined Bachelor's and Master's programs, i.e., the 150-hour combined or accelerated BS/M.S. programs. We offer two combined Bachelor of Science and Master of Science programs. In both cases, completion of the degree requirements leads to the awarding of two degrees. In one, the degrees awarded are the Computer Science BS and the Master of Science in Computer Science; in the other, the degrees are the Computer Science BS and the Master of Science in Software and Security Engineering. Depending on the options of the master's programs, the combined programs allow dual counts of up to nine credits. Students choosing the combined degree program would be admitted initially as pursuing a Computer Science BS. The graduate component of the program would be added upon admission to the master's degree. Accepted students can begin taking their graduate courses during their senior year. Students must be admitted to the graduate program before enrolling in graduate-level courses. These programs provide a strong background in computer science, specialization in subject tracks, and opportunities for research. A vast array of modern computing facilities are provided for graduate students. The on-campus High Performance Computing Center (HPCC) houses several high−performance computer systems, along with a panoramic theater for graphic and visualization demonstrations. Our graduates have been employed in many top companies including Microsoft, Meta, LinkedIn, Amazon, Google, Apple, Oracle, VMware, HPE, Nvidia, Dell, Adobe, IBM, NASA, as well as in banking industry, investment firms, and other industry sectors. Our PhD graduates have joined tier-one research universities and teaching universities as professors and national laboratories as research scientists. Our graduates are also successful in entrepreneurship and creating their own businesses.
# * All committee members must belong to the graduate faculty. At a minimum, the committee must include: Chair or Co−Chair from the Department of Computer Science at the rank of Assistant, Associate, or Full Professor. Two other committee members, one of which must be from the minor department if the minor is part of the student's degree plan.
#
#  Q: How many faculty members are in the department of computer science at Texas Tech?
#  A:

# %%
#lets ask a question
answer_query_with_context("How many faculty members are in the department of computer science at Texas Tech?", df, document_embeddings)
# Out:
# inside get_embedding
# Selected 2 document sections:
# 0
# 19
# '18'

# %% [markdown]
# ### Make UI

# %%
# Bare bones UI
session = input("What would you like to name your session? ")

print("type 'end' or 'quit' to end session")

while not re.search('end|End|quit|Quit', session): #problem: what if end or quit is part of the question
    question = input("Question: ")
    answer = answer_query_with_context(question, df, document_embeddings)
    print(answer)
    session = question

print("Ending session ... ")
# Out:
# What would you like to name your session? how many credits does a certificate require
# type 'end' or 'quit' to end session
# Question: how many credits does a certificate require
# inside get_embedding
# Selected 4 document sections:
# 32
# 30
# 29
# 27
# 12 semester credit hours.
# Question: what kind of certifiacts are offered
# inside get_embedding
# Selected 5 document sections:
# 29
# 32
# 30
# 2
# 17
# The Department of Computer Science offers the Certificate in Software Engineering for those who do not need or wish to have a full graduate degree in software engineering or computer science. In addition, the department offers a Master of Science in Software and Security Engineering and a Doctor of Philosophy in Computer Science.
# Question: quit
# inside get_embedding
# Selected 5 document sections:
# 9
# 23
# 10
# 30
# 29
# I don't know.
# Ending session ...

# %%
# GUI
